# %% [markdown]
# Notebook for creating data

# %%
from faker import Faker
import pandas as pd
import numpy as np
import random

# %%
#first_name,address,city,postal,phone,email,web,salary,birthdate,age

# %%
# https://www.cdc.gov/DiseasesConditions/az/a.html
# https://www.nhsinform.scot/illnesses-and-conditions/a-to-z

# %%
#https://www.kaggle.com/datasets/mirichoi0218/insurance
insurance = pd.read_csv('Data/insurance.csv')

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#https://www.irs.gov/statistics/soi-tax-stats-individual-income-tax-statistics-2019-zip-code-data-soi
irs = pd.read_csv('Data/19zpallagi.csv')

# %%
irs
# Out:
#         STATEFIPS STATE  zipcode  agi_stub        N1     mars1     MARS2  \
# 0               1    AL        0         1  778210.0  491030.0   84770.0
# 1               1    AL        0         2  525940.0  247140.0  123910.0
# 2               1    AL        0         3  285700.0  105140.0  128140.0
# 3               1    AL        0         4  179070.0   38820.0  123110.0
# 4               1    AL        0         5  257010.0   28180.0  216740.0
# ...           ...   ...      ...       ...       ...       ...       ...
# 166154         56    WY    99999         2    3370.0    1930.0     920.0
# 166155         56    WY    99999         3    2340.0    1070.0    1030.0
# 166156         56    WY    99999         4    1740.0     530.0    1090.0
# 166157         56    WY    99999         5    2740.0     440.0    2230.0
# 166158         56    WY    99999         6     850.0     150.0     710.0
#
#            MARS4       ELF    CPREP  ...  N85300  A85300    N11901    A11901  \
# ...

# %%
irs.groupby('zipcode').count()
# Out:
#          STATEFIPS  STATE  agi_stub   N1  mars1  MARS2  MARS4  ELF  CPREP  \
# zipcode
# 0              306    306       306  306    306    306    306  306    306
# 1001             6      6         6    6      6      6      6    6      6
# 1002             6      6         6    6      6      6      6    6      6
# 1005             6      6         6    6      6      6      6    6      6
# 1007             6      6         6    6      6      6      6    6      6
# ...            ...    ...       ...  ...    ...    ...    ...  ...    ...
# 99827            6      6         6    6      6      6      6    6      6
# 99833            6      6         6    6      6      6      6    6      6
# 99835            6      6         6    6      6      6      6    6      6
# 99901            6      6         6    6      6      6      6    6      6
# 99999          306    306       306  306    306    306    306  306    306
#
# ...

# %%
#https://www.kaggle.com/datasets/johnsmith88/heart-disease-dataset?resource=download
heart = pd.read_csv('Data/heart.csv')

# %%
heart
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
diseases = ['Asthma','Diabetes','Bronchitis','Dementia']
output = [np.random.choice(diseases, p=[0.1,0.5,0.2,0.2]) for x in range(500)]

# %%
from anonympy.pandas.utils import load_dataset

# %%
big_fake = load_dataset('big')
big_fake
# Out:
#     first_name             address                 city         phone  \
# 0      Aleshia        14 Taylor St            Wombourne  01835-703597
# 1         Evan         5 Binney St         Central Ward  01937-864715
# 2       France        8 Moor Place            Wombourne  01347-368222
# 3      Ulysses       505 Exeter Rd         Everton Ward  01912-771311
# 4       Tyisha   5396 Forth Street          Castle Ward  01547-429341
# ..         ...                 ...                  ...           ...
# 495      Avery  9166 Devon St #905  Central Buchan Ward  01748-625058
# 496       Reid        70 Foster St  Central Buchan Ward  01916-963261
# 497  Charlette     714 Fonthill Rd  Central Buchan Ward  01888-152110
# 498  Celestina         9 Milton St             Westbury  01877-379681
# 499         Mi     6 Norwood Grove         Everton Ward  01451-785624
#
#                           email                                          web  \
# ...

# %%
big_fake['medical_condition'] = output

# %%
big_fake
# Out:
#     first_name             address                 city         phone  \
# 0      Aleshia        14 Taylor St            Wombourne  01835-703597
# 1         Evan         5 Binney St         Central Ward  01937-864715
# 2       France        8 Moor Place            Wombourne  01347-368222
# 3      Ulysses       505 Exeter Rd         Everton Ward  01912-771311
# 4       Tyisha   5396 Forth Street          Castle Ward  01547-429341
# ..         ...                 ...                  ...           ...
# 495      Avery  9166 Devon St #905  Central Buchan Ward  01748-625058
# 496       Reid        70 Foster St  Central Buchan Ward  01916-963261
# 497  Charlette     714 Fonthill Rd  Central Buchan Ward  01888-152110
# 498  Celestina         9 Milton St             Westbury  01877-379681
# 499         Mi     6 Norwood Grove         Everton Ward  01451-785624
#
#                           email                                          web  \
# ...

# %%
big_fake.to_csv('big_fake.csv')

# %%
fake = Faker()

# %%
amount = 500

# %%
people = []

# %%
for _ in range(amount):
    people.append({'name': fake.name(), 
         'address': fake.address(),
         'city': fake.city(),
         'company': fake.company(),
         'date_of_birth': fake.date_of_birth(),
         'email': fake.email(),
         'license_plate': fake.license_plate()})

# %%
pd.DataFrame(people)
# Out:
#                  name                                            address  \
# 0         Howard Hall    1539 Hannah Lake Apt. 614\nThomastown, SD 85851
# 1         Allen Clark    4309 Amy Path Apt. 797\nDanielleshire, PA 65593
# 2      Tracy Anderson          847 Caldwell Track\nSouth David, UT 34128
# 3        Derek Bowers    4364 Mendoza Rest Suite 977\nLarafort, NC 26152
# 4         Brian Avila  412 Phyllis Harbor Apt. 829\nNew Elizabethshir...
# ..                ...                                                ...
# 495   Jill Richardson              204 Miller Cape\nBensonview, RI 90372
# 496  Brenda Rasmussen                          USCGC Baker\nFPO AE 16391
# 497      Stacey Quinn                   Unit 6050 Box 0622\nDPO AE 40279
# 498       Jason Walsh     78013 Dennis Gateway\nWest Cindytown, ME 44113
# 499       John Larson  9533 Alexander Fork\nPort Kimberlymouth, WV 76453
#
#                    city                      company date_of_birth  \
# ...

# %%
names = (
    'age',
    'workclass', #Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
    'fnlwgt', # "weight" of that person in the dataset (i.e. how many people does that person represent) -> https://www.kansascityfed.org/research/datamuseum/cps/coreinfo/keyconcepts/weights
    'education',
    'education-num',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'capital-gain',
    'capital-loss',
    'hours-per-week',
    'native-country',
    'income',
)

# %%
df = pd.read_csv("K-Anonymity-master/data/k-anonymity/adult.all.txt", sep=", ", header=None, names=names, index_col=False, engine='python');# We load the data using Pandas

# %%
df
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64                 ?  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# ...

# %%
diseases = ['Asthma','Diabetes','Bronchitis','Dementia','Diarrhoea','Epilepsy','Erectile dysfunction','Flatulence']
p= np.random.gamma(3, 1, len(diseases))
p = p/p.sum()
output = [np.random.choice(diseases, p=p) for x in range(48842)]

# %%
df['medical_condition'] = output

# %%
df
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64                 ?  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# ...

# %%
df.to_csv('df.csv')
